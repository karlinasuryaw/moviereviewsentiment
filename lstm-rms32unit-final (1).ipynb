# %% [markdown]
# Import Library yang Dibutuhkan

# %%
# Import Library yang akan digunakan

import pandas as pd
import nltk, os, re, string
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, LSTM, Dropout, Dense, Embedding, Flatten, GlobalMaxPool1D, SpatialDropout1D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from tensorflow.keras.utils import to_categorical
from sklearn.feature_extraction.text import CountVectorizer
import csv
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Load Dataset

# %%
dataframe = pd.read_csv('https://raw.githubusercontent.com/karlinasuryaw/moviesentiment/main/data14k_new.csv')
dataframe.head(11)
# Out:
#     Unnamed: 0                       title  \
# 0            0  10 Cloverfield Lane 2016\n
# 1            1  10 Cloverfield Lane 2016\n
# 2            2  10 Cloverfield Lane 2016\n
# 3            3  10 Cloverfield Lane 2016\n
# 4            4  10 Cloverfield Lane 2016\n
# 5            5  10 Cloverfield Lane 2016\n
# 6            6  10 Cloverfield Lane 2016\n
# 7            7  10 Cloverfield Lane 2016\n
# 8            8  10 Cloverfield Lane 2016\n
# 9            9  10 Cloverfield Lane 2016\n
# 10          10  10 Cloverfield Lane 2016\n
#
#                                                review  score
# 0   This movie is full of suspense. It makes you g...      0
# 1   I'll leave this review fairly concise. <br/><b...      0
# 2   I give the 5/10 out of the credit I owe to the...      0
# 3   First of all, I must say that I was expecting ...      0
# 4   I never write reviews. ever. This is probably ...      0
# 5   Goodman plays Howard, a paranoid psychopath an...      0
# 6   Many movie lovers will leave this film with a ...      0
# 7   Awful does not even begin to describe this mes...      0
# 8   I loved Cloverfield which for me was one of th...      0
# 9   May contain spoilers so read at your own risk....      0
# 10  How much did the producer pay the critics on r...      0

# %% [markdown]
# Menghitung Jumlah Data Berdasarkan Judul Film

# %%
dataframe.title.value_counts()
# Out:
# Dunkirk 2017                              90
# Uri The Surgical Strike 2019              90
# Spectre 2015                              90
# Southpaw 2015                             90
# Spider-Man Into the Spider-Verse 2018     90
#                                           ..
# Youth 2015                                58
# Little Boy 2015                           58
# Popstar Never Stop Never Stopping 2016    55
# M.S. Dhoni The Untold Story 2016          52
# Sing Street 2016                          50
# Name: title, Length: 165, dtype: int64

# %% [markdown]
# Menghapus kolom yang tidak digunakan

# %%
dataframe = dataframe.drop(columns = ['Unnamed: 0'])
dataframe.head(11)
# Out:
#                          title  \
# 0   10 Cloverfield Lane 2016\n
# 1   10 Cloverfield Lane 2016\n
# 2   10 Cloverfield Lane 2016\n
# 3   10 Cloverfield Lane 2016\n
# 4   10 Cloverfield Lane 2016\n
# 5   10 Cloverfield Lane 2016\n
# 6   10 Cloverfield Lane 2016\n
# 7   10 Cloverfield Lane 2016\n
# 8   10 Cloverfield Lane 2016\n
# 9   10 Cloverfield Lane 2016\n
# 10  10 Cloverfield Lane 2016\n
#
#                                                review  score
# 0   This movie is full of suspense. It makes you g...      0
# 1   I'll leave this review fairly concise. <br/><b...      0
# 2   I give the 5/10 out of the credit I owe to the...      0
# 3   First of all, I must say that I was expecting ...      0
# 4   I never write reviews. ever. This is probably ...      0
# 5   Goodman plays Howard, a paranoid psychopath an...      0
# 6   Many movie lovers will leave this film with a ...      0
# 7   Awful does not even begin to describe this mes...      0
# 8   I loved Cloverfield which for me was one of th...      0
# 9   May contain spoilers so read at your own risk....      0
# 10  How much did the producer pay the critics on r...      0

# %%
# Total data

dataframe.shape
# Out:
# (14000, 3)

# %% [markdown]
# Menghitung Jumlah Data per Kategori Sentimen (Sentimen Positif score 1 & Sentimen Negatif Score 0)

# %%
dataframe.groupby(['score']).count()
# Out:
#        title  review
# score
# 0       7000    7000
# 1       7000    7000

# %%
plt.figure(figsize = (12, 6))
sns.countplot(dataframe.score)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='score', ylabel='count'>

# %% [markdown]
# Text Preprocessing

# %% [markdown]
# Lowercase

# %%
dataframe.title = dataframe.title.apply(lambda x: x.lower())
dataframe.review = dataframe.review.apply(lambda x: x.lower())

# %% [markdown]
# Data Cleansing

# %%
dataframe.head(11)
# Out:
#                          title  \
# 0   10 cloverfield lane 2016\n
# 1   10 cloverfield lane 2016\n
# 2   10 cloverfield lane 2016\n
# 3   10 cloverfield lane 2016\n
# 4   10 cloverfield lane 2016\n
# 5   10 cloverfield lane 2016\n
# 6   10 cloverfield lane 2016\n
# 7   10 cloverfield lane 2016\n
# 8   10 cloverfield lane 2016\n
# 9   10 cloverfield lane 2016\n
# 10  10 cloverfield lane 2016\n
#
#                                                review  score
# 0   this movie is full of suspense. it makes you g...      0
# 1   i'll leave this review fairly concise. <br/><b...      0
# 2   i give the 5/10 out of the credit i owe to the...      0
# 3   first of all, i must say that i was expecting ...      0
# 4   i never write reviews. ever. this is probably ...      0
# 5   goodman plays howard, a paranoid psychopath an...      0
# 6   many movie lovers will leave this film with a ...      0
# 7   awful does not even begin to describe this mes...      0
# 8   i loved cloverfield which for me was one of th...      0
# 9   may contain spoilers so read at your own risk....      0
# 10  how much did the producer pay the critics on r...      0

# %%
#menghapus tanda baca
def cleaner(data):
    return(data.translate(str.maketrans('','', string.punctuation)))
dataframe.title = dataframe.title.apply(lambda x: cleaner(x))
dataframe.review = dataframe.review.apply(lambda x: cleaner(x))

# %%
dataframe.head(11)
# Out:
#                          title  \
# 0   10 cloverfield lane 2016\n
# 1   10 cloverfield lane 2016\n
# 2   10 cloverfield lane 2016\n
# 3   10 cloverfield lane 2016\n
# 4   10 cloverfield lane 2016\n
# 5   10 cloverfield lane 2016\n
# 6   10 cloverfield lane 2016\n
# 7   10 cloverfield lane 2016\n
# 8   10 cloverfield lane 2016\n
# 9   10 cloverfield lane 2016\n
# 10  10 cloverfield lane 2016\n
#
#                                                review  score
# 0   this movie is full of suspense it makes you gu...      0
# 1   ill leave this review fairly concise brbrthis ...      0
# 2   i give the 510 out of the credit i owe to the ...      0
# 3   first of all i must say that i was expecting s...      0
# 4   i never write reviews ever this is probably my...      0
# 5   goodman plays howard a paranoid psychopath and...      0
# 6   many movie lovers will leave this film with a ...      0
# 7   awful does not even begin to describe this mes...      0
# 8   i loved cloverfield which for me was one of th...      0
# 9   may contain spoilers so read at your own riskb...      0
# 10  how much did the producer pay the critics on r...      0

# %% [markdown]
# Stopword Removal

# %%
stwrds = stopwords.words('english')
def stopword(data):
    return(' '.join([w for w in data.split() if w not in stwrds ]))
dataframe.title = dataframe.title.apply(lambda x: stopword(x))
dataframe.review = dataframe.review.apply(lambda x: stopword(x))

# %%
dataframe.head(11)
# Out:
#                        title  \
# 0   10 cloverfield lane 2016
# 1   10 cloverfield lane 2016
# 2   10 cloverfield lane 2016
# 3   10 cloverfield lane 2016
# 4   10 cloverfield lane 2016
# 5   10 cloverfield lane 2016
# 6   10 cloverfield lane 2016
# 7   10 cloverfield lane 2016
# 8   10 cloverfield lane 2016
# 9   10 cloverfield lane 2016
# 10  10 cloverfield lane 2016
#
#                                                review  score
# 0   movie full suspense makes guess real happens w...      0
# 1   ill leave review fairly concise brbrthis film ...      0
# 2   give 510 credit owe original writers fascinati...      0
# 3   first must say expecting something different c...      0
# 4   never write reviews ever probably first everbr...      0
# 5   goodman plays howard paranoid psychopath propr...      0
# 6   many movie lovers leave film dilemma swirling ...      0
# 7   awful even begin describe mess movie absolutel...      0
# 8   loved cloverfield one best films 21st century ...      0
# 9   may contain spoilers read riskbrbrpretty much ...      0
# 10  much producer pay critics rotten tomato write ...      0

# %% [markdown]
# #### remove number

# %%
dataframe['review'] = dataframe['review'].str.replace(r'\d+','')
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
dataframe.head(11)
# Out:
#                        title  \
# 0   10 cloverfield lane 2016
# 1   10 cloverfield lane 2016
# 2   10 cloverfield lane 2016
# 3   10 cloverfield lane 2016
# 4   10 cloverfield lane 2016
# 5   10 cloverfield lane 2016
# 6   10 cloverfield lane 2016
# 7   10 cloverfield lane 2016
# 8   10 cloverfield lane 2016
# 9   10 cloverfield lane 2016
# 10  10 cloverfield lane 2016
#
#                                                review  score
# 0   movie full suspense makes guess real happens w...      0
# 1   ill leave review fairly concise brbrthis film ...      0
# 2   give  credit owe original writers fascinating ...      0
# 3   first must say expecting something different c...      0
# 4   never write reviews ever probably first everbr...      0
# 5   goodman plays howard paranoid psychopath propr...      0
# 6   many movie lovers leave film dilemma swirling ...      0
# 7   awful even begin describe mess movie absolutel...      0
# 8   loved cloverfield one best films st century sa...      0
# 9   may contain spoilers read riskbrbrpretty much ...      0
# 10  much producer pay critics rotten tomato write ...      0

# %%
X = dataframe['review']
y = dataframe["score"]
y = to_categorical(y)

# %% [markdown]
# Merubah text menjadi sequences of number dan Menentukan Jumlah vocab

# %%
from sklearn.model_selection import StratifiedKFold , KFold ,RepeatedKFold

# %%
#jml_vocab = len(tokenizer.index_word)+1

# %%
jumlah_vocab = 10000
output_dim = 300

# %%
tokenizer = Tokenizer(num_words=10000, oov_token='OOV')
tokenizer.fit_on_texts(X)

# %%
sequence_text = tokenizer.texts_to_sequences(X)
X = pad_sequences(sequence_text)

# %%
print(tokenizer.texts_to_sequences(['I love this movie']))
print(tokenizer.texts_to_sequences(['I hate the actor of this movie']))
# Out:
# [[1, 45, 1, 2]]
# [[1, 486, 1, 206, 1, 1, 2]]

# %% [markdown]
# Split data 90% 10%

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Storing the average of all predictions

data_kfold = pd.DataFrame()



# k-fold
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

batch_size_tes=[32, 64, 128, 256]

# Variable for keeping count of split we are executing
j = 0
for batch in batch_size_tes:
  # K-fold Train and test for each split
  globals()['data_kfold_batch%s'%batch] =  pd.DataFrame()
  globals()['jumlah_fold_batch%s'%batch] =  pd.DataFrame()
  for train, test in kfold.split(X_train, y_train):
      
      X_train_fold, X_test_fold = X_train[train], X_train[test]
      y_train_fold, y_test_fold = y_train[train], y_train[test]
          
      j+=1
      globals()['jumlah_fold_batch%s'%batch][j] = [len(train), len(test)] 

      globals()['model_fold_%s' %batch] = tf.keras.Sequential([
          Embedding(jumlah_vocab, output_dim),
          SpatialDropout1D(0.5),
          LSTM(32, return_sequences=True),
          LSTM(32, kernel_regularizer=(tf.keras.regularizers.L2(1e-3)), recurrent_regularizer=(tf.keras.regularizers.L2(1e-3))),
          Dense(8, activation='relu'),
          Dropout(0.5),
          Dense(2, activation='sigmoid')
      ])

      globals()['model_fold_%s' %batch].compile(optimizer='rmsprop', 
                    loss='binary_crossentropy', 
                    metrics=['accuracy'])

      globals()['model_fold_%s' %batch].summary()
      

      globals()['model_fold_%s' %batch].fit(
          X_train_fold,
          y_train_fold,
          batch_size=batch,
          epochs=5,
          validation_data=(X_test_fold, y_test_fold)
          
          ) 
          
      
      predicted_class_indices = globals()['model_fold_%s' %batch].evaluate(X_test_fold,y_test_fold)
      globals()['data_kfold_batch%s'%batch][j] = predicted_class_indices
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 32)          42624
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 315/315 [==============================] - 26s 75ms/step - loss: 0.6394 - accuracy: 0.6862 - val_loss: 0.5537 - val_accuracy: 0.7452
# Epoch 2/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.4942 - accuracy: 0.8031 - val_loss: 0.4612 - val_accuracy: 0.7881
# Epoch 3/5
# 315/315 [==============================] - 23s 72ms/step - loss: 0.4367 - accuracy: 0.8365 - val_loss: 0.4393 - val_accuracy: 0.7972
# Epoch 4/5
# 315/315 [==============================] - 23s 72ms/step - loss: 0.3849 - accuracy: 0.8606 - val_loss: 0.4555 - val_accuracy: 0.7996
# Epoch 5/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3585 - accuracy: 0.8703 - val_loss: 0.4820 - val_accuracy: 0.7944
# 79/79 [==============================] - 2s 31ms/step - loss: 0.4820 - accuracy: 0.7944
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_2 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, None, 32)          42624
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 315/315 [==============================] - 26s 74ms/step - loss: 0.6346 - accuracy: 0.6562 - val_loss: 0.5060 - val_accuracy: 0.7726
# Epoch 2/5
# 315/315 [==============================] - 23s 72ms/step - loss: 0.4851 - accuracy: 0.7767 - val_loss: 0.4618 - val_accuracy: 0.7833
# Epoch 3/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.4164 - accuracy: 0.8212 - val_loss: 0.4726 - val_accuracy: 0.7853
# Epoch 4/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3817 - accuracy: 0.8486 - val_loss: 0.4576 - val_accuracy: 0.7921
# Epoch 5/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3509 - accuracy: 0.8573 - val_loss: 0.4643 - val_accuracy: 0.7810
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4643 - accuracy: 0.7810
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, None, 32)          42624
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 315/315 [==============================] - 26s 74ms/step - loss: 0.6507 - accuracy: 0.6762 - val_loss: 0.5477 - val_accuracy: 0.7710
# Epoch 2/5
# 315/315 [==============================] - 23s 72ms/step - loss: 0.5302 - accuracy: 0.7837 - val_loss: 0.4927 - val_accuracy: 0.7774
# Epoch 3/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.4486 - accuracy: 0.8265 - val_loss: 0.5171 - val_accuracy: 0.7730
# Epoch 4/5
# 315/315 [==============================] - 23s 72ms/step - loss: 0.3898 - accuracy: 0.8529 - val_loss: 0.5268 - val_accuracy: 0.7722
# Epoch 5/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3425 - accuracy: 0.8752 - val_loss: 0.5465 - val_accuracy: 0.7722
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5465 - accuracy: 0.7722
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_4 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, None, 32)          42624
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 315/315 [==============================] - 27s 74ms/step - loss: 0.6526 - accuracy: 0.6589 - val_loss: 0.5483 - val_accuracy: 0.7548
# Epoch 2/5
# 315/315 [==============================] - 23s 74ms/step - loss: 0.5070 - accuracy: 0.7889 - val_loss: 0.4893 - val_accuracy: 0.7778
# Epoch 3/5
# 315/315 [==============================] - 23s 74ms/step - loss: 0.4325 - accuracy: 0.8252 - val_loss: 0.4614 - val_accuracy: 0.7893
# Epoch 4/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3788 - accuracy: 0.8445 - val_loss: 0.5185 - val_accuracy: 0.7833
# Epoch 5/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3378 - accuracy: 0.8648 - val_loss: 0.4967 - val_accuracy: 0.7782
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4967 - accuracy: 0.7782
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_5 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 315/315 [==============================] - 26s 75ms/step - loss: 0.6256 - accuracy: 0.6795 - val_loss: 0.5449 - val_accuracy: 0.7496
# Epoch 2/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.4788 - accuracy: 0.7999 - val_loss: 0.4753 - val_accuracy: 0.7817
# Epoch 3/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.4141 - accuracy: 0.8338 - val_loss: 0.4976 - val_accuracy: 0.7726
# Epoch 4/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3777 - accuracy: 0.8524 - val_loss: 0.4845 - val_accuracy: 0.7821
# Epoch 5/5
# 315/315 [==============================] - 23s 73ms/step - loss: 0.3459 - accuracy: 0.8640 - val_loss: 0.4804 - val_accuracy: 0.7786
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4804 - accuracy: 0.7786
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_12 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_12 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 158/158 [==============================] - 17s 86ms/step - loss: 0.6932 - accuracy: 0.6347 - val_loss: 0.5859 - val_accuracy: 0.7782
# Epoch 2/5
# 158/158 [==============================] - 13s 84ms/step - loss: 0.5641 - accuracy: 0.7908 - val_loss: 0.5717 - val_accuracy: 0.7417
# Epoch 3/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.4825 - accuracy: 0.8330 - val_loss: 0.5071 - val_accuracy: 0.7611
# Epoch 4/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.4123 - accuracy: 0.8580 - val_loss: 0.4647 - val_accuracy: 0.7861
# Epoch 5/5
# 158/158 [==============================] - 13s 82ms/step - loss: 0.3594 - accuracy: 0.8803 - val_loss: 0.5000 - val_accuracy: 0.7913
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5000 - accuracy: 0.7913
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_7 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 158/158 [==============================] - 16s 86ms/step - loss: 0.6492 - accuracy: 0.6729 - val_loss: 0.5285 - val_accuracy: 0.7690
# Epoch 2/5
# 158/158 [==============================] - 13s 84ms/step - loss: 0.4937 - accuracy: 0.7994 - val_loss: 0.4801 - val_accuracy: 0.7762
# Epoch 3/5
# 158/158 [==============================] - 13s 82ms/step - loss: 0.4201 - accuracy: 0.8333 - val_loss: 0.4830 - val_accuracy: 0.7786
# Epoch 4/5
# 158/158 [==============================] - 13s 82ms/step - loss: 0.3657 - accuracy: 0.8589 - val_loss: 0.5016 - val_accuracy: 0.7829
# Epoch 5/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.3232 - accuracy: 0.8783 - val_loss: 0.5072 - val_accuracy: 0.7659
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5072 - accuracy: 0.7659
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_8 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_16 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 158/158 [==============================] - 17s 90ms/step - loss: 0.6703 - accuracy: 0.6578 - val_loss: 0.5669 - val_accuracy: 0.7393
# Epoch 2/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.5242 - accuracy: 0.8063 - val_loss: 0.5309 - val_accuracy: 0.7655
# Epoch 3/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.4472 - accuracy: 0.8474 - val_loss: 0.5111 - val_accuracy: 0.7770
# Epoch 4/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.3992 - accuracy: 0.8741 - val_loss: 0.5080 - val_accuracy: 0.7679
# Epoch 5/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.3531 - accuracy: 0.8894 - val_loss: 0.8017 - val_accuracy: 0.7567
# 79/79 [==============================] - 2s 29ms/step - loss: 0.8017 - accuracy: 0.7567
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_9 (Spatial (None, None, 300)         0
# _________________________________________________________________
# lstm_18 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_18 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 158/158 [==============================] - 16s 87ms/step - loss: 0.6641 - accuracy: 0.6615 - val_loss: 0.5327 - val_accuracy: 0.7579
# Epoch 2/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.5040 - accuracy: 0.7943 - val_loss: 0.4988 - val_accuracy: 0.7694
# Epoch 3/5
# 158/158 [==============================] - 13s 82ms/step - loss: 0.4240 - accuracy: 0.8358 - val_loss: 0.4697 - val_accuracy: 0.7865
# Epoch 4/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.3719 - accuracy: 0.8547 - val_loss: 0.5040 - val_accuracy: 0.7806
# Epoch 5/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.3341 - accuracy: 0.8791 - val_loss: 0.5445 - val_accuracy: 0.7794
# 79/79 [==============================] - 2s 27ms/step - loss: 0.5445 - accuracy: 0.7794
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_10 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_20 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 158/158 [==============================] - 17s 87ms/step - loss: 0.6744 - accuracy: 0.6455 - val_loss: 0.5763 - val_accuracy: 0.7437
# Epoch 2/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.5145 - accuracy: 0.7905 - val_loss: 0.4991 - val_accuracy: 0.7718
# Epoch 3/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.4229 - accuracy: 0.8221 - val_loss: 0.5669 - val_accuracy: 0.7571
# Epoch 4/5
# 158/158 [==============================] - 13s 82ms/step - loss: 0.3683 - accuracy: 0.8369 - val_loss: 0.5637 - val_accuracy: 0.7734
# Epoch 5/5
# 158/158 [==============================] - 13s 83ms/step - loss: 0.3346 - accuracy: 0.8596 - val_loss: 0.5118 - val_accuracy: 0.7766
# 79/79 [==============================] - 2s 30ms/step - loss: 0.5118 - accuracy: 0.7766
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_11 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_11 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_23 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_22 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 112ms/step - loss: 0.6967 - accuracy: 0.6268 - val_loss: 0.5720 - val_accuracy: 0.7552
# Epoch 2/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5440 - accuracy: 0.7797 - val_loss: 0.4955 - val_accuracy: 0.7873
# Epoch 3/5
# 79/79 [==============================] - 8s 106ms/step - loss: 0.4583 - accuracy: 0.8267 - val_loss: 0.4498 - val_accuracy: 0.8067
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4053 - accuracy: 0.8588 - val_loss: 0.4731 - val_accuracy: 0.7845
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3522 - accuracy: 0.8832 - val_loss: 0.4755 - val_accuracy: 0.8040
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4755 - accuracy: 0.8040
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_12 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_12 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_24 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_25 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_24 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_25 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6945 - accuracy: 0.6363 - val_loss: 0.5755 - val_accuracy: 0.7607
# Epoch 2/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5557 - accuracy: 0.7659 - val_loss: 0.5138 - val_accuracy: 0.7758
# Epoch 3/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4711 - accuracy: 0.8433 - val_loss: 0.4757 - val_accuracy: 0.7865
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4060 - accuracy: 0.8723 - val_loss: 0.5247 - val_accuracy: 0.7437
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3622 - accuracy: 0.8922 - val_loss: 0.4974 - val_accuracy: 0.7889
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4974 - accuracy: 0.7889
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_13 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_13 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_26 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_27 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_26 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 13s 120ms/step - loss: 0.6916 - accuracy: 0.6464 - val_loss: 0.5903 - val_accuracy: 0.7393
# Epoch 2/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5659 - accuracy: 0.7678 - val_loss: 0.5456 - val_accuracy: 0.7540
# Epoch 3/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4765 - accuracy: 0.8209 - val_loss: 0.5119 - val_accuracy: 0.7575
# Epoch 4/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.4087 - accuracy: 0.8581 - val_loss: 0.5199 - val_accuracy: 0.7857
# Epoch 5/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.3569 - accuracy: 0.8797 - val_loss: 0.5364 - val_accuracy: 0.7627
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5364 - accuracy: 0.7627
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_14 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_28 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_28 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 112ms/step - loss: 0.6796 - accuracy: 0.6505 - val_loss: 0.5646 - val_accuracy: 0.7631
# Epoch 2/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.5136 - accuracy: 0.7910 - val_loss: 0.4716 - val_accuracy: 0.7873
# Epoch 3/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4253 - accuracy: 0.8379 - val_loss: 0.4795 - val_accuracy: 0.7706
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3704 - accuracy: 0.8627 - val_loss: 0.4769 - val_accuracy: 0.7798
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3236 - accuracy: 0.8806 - val_loss: 0.5412 - val_accuracy: 0.7730
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5412 - accuracy: 0.7730
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_15 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_30 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_30 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 115ms/step - loss: 0.7146 - accuracy: 0.6390 - val_loss: 0.6425 - val_accuracy: 0.7437
# Epoch 2/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.6076 - accuracy: 0.7654 - val_loss: 0.5882 - val_accuracy: 0.7278
# Epoch 3/5
# 79/79 [==============================] - 8s 103ms/step - loss: 0.5236 - accuracy: 0.8222 - val_loss: 0.5067 - val_accuracy: 0.7782
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4578 - accuracy: 0.8596 - val_loss: 0.5116 - val_accuracy: 0.7861
# Epoch 5/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.4101 - accuracy: 0.8795 - val_loss: 0.4919 - val_accuracy: 0.7782
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4919 - accuracy: 0.7782
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_16 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_16 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_32 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 40/40 [==============================] - 10s 162ms/step - loss: 0.7232 - accuracy: 0.6059 - val_loss: 0.6125 - val_accuracy: 0.7349
# Epoch 2/5
# 40/40 [==============================] - 6s 149ms/step - loss: 0.5787 - accuracy: 0.7498 - val_loss: 0.5305 - val_accuracy: 0.7790
# Epoch 3/5
# 40/40 [==============================] - 6s 147ms/step - loss: 0.5011 - accuracy: 0.7995 - val_loss: 0.5427 - val_accuracy: 0.7567
# Epoch 4/5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4313 - accuracy: 0.8235 - val_loss: 0.4807 - val_accuracy: 0.7786
# Epoch 5/5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.3911 - accuracy: 0.8476 - val_loss: 0.4943 - val_accuracy: 0.7829
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4943 - accuracy: 0.7829
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_17 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_17 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_34 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_35 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_34 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 40/40 [==============================] - 9s 161ms/step - loss: 0.7248 - accuracy: 0.5957 - val_loss: 0.6389 - val_accuracy: 0.7183
# Epoch 2/5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.5971 - accuracy: 0.7702 - val_loss: 0.5452 - val_accuracy: 0.7663
# Epoch 3/5
# 40/40 [==============================] - 6s 144ms/step - loss: 0.5192 - accuracy: 0.8336 - val_loss: 0.5049 - val_accuracy: 0.7881
# Epoch 4/5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4681 - accuracy: 0.8621 - val_loss: 0.4931 - val_accuracy: 0.7706
# Epoch 5/5
# 40/40 [==============================] - 6s 150ms/step - loss: 0.4277 - accuracy: 0.8817 - val_loss: 0.5362 - val_accuracy: 0.7722
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5362 - accuracy: 0.7722
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_18 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_18 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_36 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_37 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_36 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_37 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 40/40 [==============================] - 9s 159ms/step - loss: 0.7301 - accuracy: 0.6184 - val_loss: 0.6558 - val_accuracy: 0.6885
# Epoch 2/5
# 40/40 [==============================] - 6s 142ms/step - loss: 0.6441 - accuracy: 0.7449 - val_loss: 0.6148 - val_accuracy: 0.7429
# Epoch 3/5
# 40/40 [==============================] - 6s 150ms/step - loss: 0.5910 - accuracy: 0.7941 - val_loss: 0.5970 - val_accuracy: 0.7504
# Epoch 4/5
# 40/40 [==============================] - 6s 144ms/step - loss: 0.5489 - accuracy: 0.8168 - val_loss: 0.6002 - val_accuracy: 0.7504
# Epoch 5/5
# 40/40 [==============================] - 6s 143ms/step - loss: 0.5098 - accuracy: 0.8439 - val_loss: 0.6347 - val_accuracy: 0.7548
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6347 - accuracy: 0.7548
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_19 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_19 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_38 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_39 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_38 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_39 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 40/40 [==============================] - 11s 163ms/step - loss: 0.7341 - accuracy: 0.5813 - val_loss: 0.6393 - val_accuracy: 0.6817
# Epoch 2/5
# 40/40 [==============================] - 6s 145ms/step - loss: 0.6292 - accuracy: 0.7452 - val_loss: 0.5842 - val_accuracy: 0.7198
# Epoch 3/5
# 40/40 [==============================] - 6s 145ms/step - loss: 0.5528 - accuracy: 0.8015 - val_loss: 0.5223 - val_accuracy: 0.7667
# Epoch 4/5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4885 - accuracy: 0.8438 - val_loss: 0.4975 - val_accuracy: 0.7825
# Epoch 5/5
# 40/40 [==============================] - 6s 147ms/step - loss: 0.4463 - accuracy: 0.8614 - val_loss: 0.5130 - val_accuracy: 0.7786
# 79/79 [==============================] - 3s 36ms/step - loss: 0.5130 - accuracy: 0.7786
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_20 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_20 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_40 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_41 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_40 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_41 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 40/40 [==============================] - 9s 162ms/step - loss: 0.7175 - accuracy: 0.6083 - val_loss: 0.6563 - val_accuracy: 0.6595
# Epoch 2/5
# 40/40 [==============================] - 6s 145ms/step - loss: 0.5786 - accuracy: 0.7483 - val_loss: 0.5466 - val_accuracy: 0.7663
# Epoch 3/5
# 40/40 [==============================] - 6s 146ms/step - loss: 0.4861 - accuracy: 0.8024 - val_loss: 0.5060 - val_accuracy: 0.7774
# Epoch 4/5
# 40/40 [==============================] - 6s 145ms/step - loss: 0.4284 - accuracy: 0.8276 - val_loss: 0.5238 - val_accuracy: 0.7817
# Epoch 5/5
# 40/40 [==============================] - 6s 150ms/step - loss: 0.3786 - accuracy: 0.8482 - val_loss: 0.5164 - val_accuracy: 0.7813
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5164 - accuracy: 0.7813

# %%
for batch in batch_size_tes:
    print(globals()['jumlah_fold_batch%s'%batch])
# Out:
#        1      2      3      4      5
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520
#       6      7      8      9      10
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520
#       11     12     13     14     15
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520
#       16     17     18     19     20
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520

# %%
data_kfold_batch32
# Out:
#           1         2         3         4         5
# 0  0.482005  0.464268  0.546508  0.496693  0.480430
# 1  0.794444  0.780952  0.772222  0.778175  0.778571

# %%
data_kfold_batch64
# Out:
#          6         7         8         9         10
# 0  0.499977  0.507191  0.801674  0.544457  0.511795
# 1  0.791270  0.765873  0.756746  0.779365  0.776587

# %%
data_kfold_batch128
# Out:
#          11        12        13        14        15
# 0  0.475455  0.497368  0.536374  0.541172  0.491938
# 1  0.803968  0.788889  0.762698  0.773016  0.778175

# %%
data_kfold_batch256
# Out:
#          16        17        18        19        20
# 0  0.494294  0.536215  0.634676  0.513025  0.516408
# 1  0.782937  0.772222  0.754762  0.778571  0.781349

# %%
data_eval_kfold = pd.DataFrame()

for batch in batch_size_tes:
    print(globals()['data_kfold_batch%s'%batch].mean(axis=1))
# Out:
# 0    0.493981
# 1    0.780873
# dtype: float64
# 0    0.573019
# 1    0.773968
# dtype: float64
# 0    0.508462
# 1    0.781349
# dtype: float64
# 0    0.538923
# 1    0.773968
# dtype: float64

# %%
# Storing the average of all predictions

data_kfold = pd.DataFrame()

# k-fold
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

epoh_tes=[3, 5, 10, 15, 20]

# Variable for keeping count of split we are executing
j = 0
for epoh in epoh_tes:
  # K-fold Train and test for each split
  globals()['data_kfold_epoh%s'%epoh] =  pd.DataFrame()
  globals()['jumlah_fold_epoh%s'%epoh]=  pd.DataFrame()

  for train, test in kfold.split(X_train, y_train):
      
      X_train_fold, X_test_fold = X_train[train], X_train[test]
      y_train_fold, y_test_fold = y_train[train], y_train[test]
          


      
      j+=1

      globals()['jumlah_fold_epoh%s'%epoh][j] = [len(train), len(test)] 
        
      globals()['model_fold_%s' %epoh] = tf.keras.Sequential([
          Embedding(jumlah_vocab, output_dim),
          SpatialDropout1D(0.5),
          LSTM(32, return_sequences=True),
          LSTM(32, kernel_regularizer=(tf.keras.regularizers.L2(1e-3)), recurrent_regularizer=(tf.keras.regularizers.L2(1e-3))),
          Dense(8, activation='relu'),
          Dropout(0.5),
          Dense(2, activation='sigmoid')
      ])

      globals()['model_fold_%s' %epoh].compile(optimizer='rmsprop', 
                    loss='binary_crossentropy', 
                    metrics=['accuracy'])

      globals()['model_fold_%s' %epoh].summary()
      

      globals()['model_fold_%s' %epoh].fit(
          X_train_fold,
          y_train_fold,
          batch_size=128,
          epochs=epoh,
          validation_data=(X_test_fold, y_test_fold)
          ) 
 
      
      predicted_class_indices = globals()['model_fold_%s' %epoh].evaluate(X_test_fold,y_test_fold)

      globals()['data_kfold_epoh%s'%epoh][j] = predicted_class_indices
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_21 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_21 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_42 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_43 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_42 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_43 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 79/79 [==============================] - 12s 114ms/step - loss: 0.7088 - accuracy: 0.6038 - val_loss: 0.6050 - val_accuracy: 0.7353
# Epoch 2/3
# 79/79 [==============================] - 8s 103ms/step - loss: 0.5883 - accuracy: 0.7367 - val_loss: 0.5095 - val_accuracy: 0.7897
# Epoch 3/3
# 79/79 [==============================] - 8s 104ms/step - loss: 0.5010 - accuracy: 0.8011 - val_loss: 0.4843 - val_accuracy: 0.7869
# 79/79 [==============================] - 2s 28ms/step - loss: 0.4843 - accuracy: 0.7869
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_22 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_22 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_44 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_45 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_44 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_45 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 79/79 [==============================] - 13s 112ms/step - loss: 0.7075 - accuracy: 0.6163 - val_loss: 0.6059 - val_accuracy: 0.7337
# Epoch 2/3
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5768 - accuracy: 0.7555 - val_loss: 0.5214 - val_accuracy: 0.7770
# Epoch 3/3
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4943 - accuracy: 0.8000 - val_loss: 0.4881 - val_accuracy: 0.7865
# 79/79 [==============================] - 2s 29ms/step - loss: 0.4881 - accuracy: 0.7865
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_23 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_23 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_46 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_47 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_46 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_47 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 79/79 [==============================] - 12s 114ms/step - loss: 0.6896 - accuracy: 0.6146 - val_loss: 0.5826 - val_accuracy: 0.7329
# Epoch 2/3
# 79/79 [==============================] - 8s 106ms/step - loss: 0.5482 - accuracy: 0.7275 - val_loss: 0.5191 - val_accuracy: 0.7631
# Epoch 3/3
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4682 - accuracy: 0.8036 - val_loss: 0.5267 - val_accuracy: 0.7552
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5267 - accuracy: 0.7552
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_24 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_24 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_48 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_49 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_48 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_49 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6896 - accuracy: 0.6411 - val_loss: 0.5587 - val_accuracy: 0.7583
# Epoch 2/3
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5243 - accuracy: 0.7969 - val_loss: 0.5078 - val_accuracy: 0.7750
# Epoch 3/3
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4291 - accuracy: 0.8467 - val_loss: 0.5426 - val_accuracy: 0.7663
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5426 - accuracy: 0.7663
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_25 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_25 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_50 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_51 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_50 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_51 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6856 - accuracy: 0.6135 - val_loss: 0.5788 - val_accuracy: 0.7464
# Epoch 2/3
# 79/79 [==============================] - 8s 104ms/step - loss: 0.5439 - accuracy: 0.7862 - val_loss: 0.5322 - val_accuracy: 0.7683
# Epoch 3/3
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4719 - accuracy: 0.8341 - val_loss: 0.6459 - val_accuracy: 0.7472
# 79/79 [==============================] - 2s 30ms/step - loss: 0.6459 - accuracy: 0.7472
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_26 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_26 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_52 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_53 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_52 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_53 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 114ms/step - loss: 0.6815 - accuracy: 0.6628 - val_loss: 0.5494 - val_accuracy: 0.7702
# Epoch 2/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5222 - accuracy: 0.7920 - val_loss: 0.4906 - val_accuracy: 0.7813
# Epoch 3/5
# 79/79 [==============================] - 8s 107ms/step - loss: 0.4419 - accuracy: 0.8418 - val_loss: 0.4673 - val_accuracy: 0.7948
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3801 - accuracy: 0.8720 - val_loss: 0.4666 - val_accuracy: 0.7913
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3374 - accuracy: 0.8908 - val_loss: 0.5131 - val_accuracy: 0.7849
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5131 - accuracy: 0.7849
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_27 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_27 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_54 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_54 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_55 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 120ms/step - loss: 0.6844 - accuracy: 0.6528 - val_loss: 0.5794 - val_accuracy: 0.7615
# Epoch 2/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5483 - accuracy: 0.7949 - val_loss: 0.5365 - val_accuracy: 0.7635
# Epoch 3/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4617 - accuracy: 0.8428 - val_loss: 0.4981 - val_accuracy: 0.7710
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3921 - accuracy: 0.8693 - val_loss: 0.5491 - val_accuracy: 0.7675
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3413 - accuracy: 0.8884 - val_loss: 0.5101 - val_accuracy: 0.7790
# 79/79 [==============================] - 2s 28ms/step - loss: 0.5101 - accuracy: 0.7790
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_28 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_28 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_56 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_57 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_56 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_57 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6826 - accuracy: 0.6553 - val_loss: 0.5794 - val_accuracy: 0.7381
# Epoch 2/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5280 - accuracy: 0.7895 - val_loss: 0.5167 - val_accuracy: 0.7647
# Epoch 3/5
# 79/79 [==============================] - 8s 106ms/step - loss: 0.4342 - accuracy: 0.8423 - val_loss: 0.4974 - val_accuracy: 0.7829
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3685 - accuracy: 0.8730 - val_loss: 0.5040 - val_accuracy: 0.7806
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3236 - accuracy: 0.8958 - val_loss: 0.5357 - val_accuracy: 0.7806
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5357 - accuracy: 0.7806
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_29 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_29 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_58 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_59 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_58 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_59 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 112ms/step - loss: 0.6887 - accuracy: 0.6475 - val_loss: 0.5766 - val_accuracy: 0.7571
# Epoch 2/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.5269 - accuracy: 0.7891 - val_loss: 0.4909 - val_accuracy: 0.7798
# Epoch 3/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4383 - accuracy: 0.8338 - val_loss: 0.5107 - val_accuracy: 0.7798
# Epoch 4/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3699 - accuracy: 0.8619 - val_loss: 0.5026 - val_accuracy: 0.7821
# Epoch 5/5
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3176 - accuracy: 0.8820 - val_loss: 0.5798 - val_accuracy: 0.7770
# 79/79 [==============================] - 2s 29ms/step - loss: 0.5798 - accuracy: 0.7770
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_30 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_30 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_60 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_60 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_61 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6950 - accuracy: 0.6577 - val_loss: 0.6226 - val_accuracy: 0.7357
# Epoch 2/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.5625 - accuracy: 0.7891 - val_loss: 0.5285 - val_accuracy: 0.7817
# Epoch 3/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.4534 - accuracy: 0.8368 - val_loss: 0.5178 - val_accuracy: 0.7802
# Epoch 4/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.3785 - accuracy: 0.8709 - val_loss: 0.4922 - val_accuracy: 0.7853
# Epoch 5/5
# 79/79 [==============================] - 8s 104ms/step - loss: 0.3374 - accuracy: 0.8861 - val_loss: 0.4998 - val_accuracy: 0.7806
# 79/79 [==============================] - 2s 30ms/step - loss: 0.4998 - accuracy: 0.7806
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_31 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_31 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_62 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_63 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_62 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_63 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 79/79 [==============================] - 12s 112ms/step - loss: 0.6923 - accuracy: 0.6410 - val_loss: 0.5843 - val_accuracy: 0.7353
# Epoch 2/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5594 - accuracy: 0.7716 - val_loss: 0.5154 - val_accuracy: 0.7683
# Epoch 3/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.4890 - accuracy: 0.8334 - val_loss: 0.5014 - val_accuracy: 0.7722
# Epoch 4/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4427 - accuracy: 0.8560 - val_loss: 0.4822 - val_accuracy: 0.7865
# Epoch 5/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.4059 - accuracy: 0.8767 - val_loss: 0.4849 - val_accuracy: 0.7806
# Epoch 6/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3802 - accuracy: 0.8874 - val_loss: 0.5384 - val_accuracy: 0.7841
# Epoch 7/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3510 - accuracy: 0.9004 - val_loss: 0.5038 - val_accuracy: 0.7651
# Epoch 8/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3326 - accuracy: 0.9011 - val_loss: 0.5021 - val_accuracy: 0.7821
# Epoch 9/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.3092 - accuracy: 0.9143 - val_loss: 0.5886 - val_accuracy: 0.7802
# Epoch 10/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2978 - accuracy: 0.9200 - val_loss: 0.6485 - val_accuracy: 0.7790
# 79/79 [==============================] - 2s 28ms/step - loss: 0.6485 - accuracy: 0.7790
# Model: "sequential_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_32 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_32 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_64 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_65 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_64 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_65 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6926 - accuracy: 0.6457 - val_loss: 0.5623 - val_accuracy: 0.7563
# Epoch 2/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5365 - accuracy: 0.7980 - val_loss: 0.5050 - val_accuracy: 0.7821
# Epoch 3/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4559 - accuracy: 0.8429 - val_loss: 0.4744 - val_accuracy: 0.7837
# Epoch 4/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3938 - accuracy: 0.8747 - val_loss: 0.5007 - val_accuracy: 0.7647
# Epoch 5/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3399 - accuracy: 0.8983 - val_loss: 0.5091 - val_accuracy: 0.7913
# Epoch 6/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3031 - accuracy: 0.9153 - val_loss: 0.5759 - val_accuracy: 0.7786
# Epoch 7/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2699 - accuracy: 0.9271 - val_loss: 0.5857 - val_accuracy: 0.7694
# Epoch 8/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2469 - accuracy: 0.9352 - val_loss: 0.6835 - val_accuracy: 0.7718
# Epoch 9/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2223 - accuracy: 0.9424 - val_loss: 0.7168 - val_accuracy: 0.7766
# Epoch 10/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1980 - accuracy: 0.9517 - val_loss: 0.7831 - val_accuracy: 0.7552
# 79/79 [==============================] - 2s 27ms/step - loss: 0.7831 - accuracy: 0.7552
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_33 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_33 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_66 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_67 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_66 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_67 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6732 - accuracy: 0.6575 - val_loss: 0.5870 - val_accuracy: 0.7155
# Epoch 2/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.5130 - accuracy: 0.7728 - val_loss: 0.4884 - val_accuracy: 0.7889
# Epoch 3/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4265 - accuracy: 0.8461 - val_loss: 0.5054 - val_accuracy: 0.7821
# Epoch 4/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3649 - accuracy: 0.8788 - val_loss: 0.5313 - val_accuracy: 0.7881
# Epoch 5/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3235 - accuracy: 0.8909 - val_loss: 0.5698 - val_accuracy: 0.7774
# Epoch 6/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2824 - accuracy: 0.9103 - val_loss: 0.6031 - val_accuracy: 0.7671
# Epoch 7/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2558 - accuracy: 0.9223 - val_loss: 0.6611 - val_accuracy: 0.7714
# Epoch 8/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2334 - accuracy: 0.9285 - val_loss: 0.7892 - val_accuracy: 0.7611
# Epoch 9/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2136 - accuracy: 0.9329 - val_loss: 0.6618 - val_accuracy: 0.7587
# Epoch 10/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1830 - accuracy: 0.9459 - val_loss: 1.0499 - val_accuracy: 0.7552
# 79/79 [==============================] - 2s 30ms/step - loss: 1.0499 - accuracy: 0.7552
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_34 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_34 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_68 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_69 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_68 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_69 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 79/79 [==============================] - 12s 112ms/step - loss: 0.6959 - accuracy: 0.6505 - val_loss: 0.6008 - val_accuracy: 0.7433
# Epoch 2/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5655 - accuracy: 0.7769 - val_loss: 0.5209 - val_accuracy: 0.7647
# Epoch 3/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4739 - accuracy: 0.8291 - val_loss: 0.5024 - val_accuracy: 0.7849
# Epoch 4/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3980 - accuracy: 0.8662 - val_loss: 0.5030 - val_accuracy: 0.7841
# Epoch 5/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3531 - accuracy: 0.8814 - val_loss: 0.5410 - val_accuracy: 0.7782
# Epoch 6/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3069 - accuracy: 0.9005 - val_loss: 0.5977 - val_accuracy: 0.7492
# Epoch 7/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2857 - accuracy: 0.9092 - val_loss: 0.5570 - val_accuracy: 0.7754
# Epoch 8/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2587 - accuracy: 0.9197 - val_loss: 0.7451 - val_accuracy: 0.7651
# Epoch 9/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2365 - accuracy: 0.9272 - val_loss: 0.7183 - val_accuracy: 0.7675
# Epoch 10/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2244 - accuracy: 0.9286 - val_loss: 0.7250 - val_accuracy: 0.7579
# 79/79 [==============================] - 2s 29ms/step - loss: 0.7250 - accuracy: 0.7579
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_35 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_35 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_70 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_71 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_70 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_71 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 79/79 [==============================] - 12s 114ms/step - loss: 0.6765 - accuracy: 0.6509 - val_loss: 0.5806 - val_accuracy: 0.7409
# Epoch 2/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5324 - accuracy: 0.7932 - val_loss: 0.5107 - val_accuracy: 0.7766
# Epoch 3/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4416 - accuracy: 0.8471 - val_loss: 0.4907 - val_accuracy: 0.7837
# Epoch 4/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3870 - accuracy: 0.8773 - val_loss: 0.5168 - val_accuracy: 0.7774
# Epoch 5/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3378 - accuracy: 0.8960 - val_loss: 0.5217 - val_accuracy: 0.7861
# Epoch 6/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3041 - accuracy: 0.9077 - val_loss: 0.5885 - val_accuracy: 0.7873
# Epoch 7/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2794 - accuracy: 0.9190 - val_loss: 0.5571 - val_accuracy: 0.7861
# Epoch 8/10
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2549 - accuracy: 0.9236 - val_loss: 0.6733 - val_accuracy: 0.7631
# Epoch 9/10
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2340 - accuracy: 0.9345 - val_loss: 0.7135 - val_accuracy: 0.7690
# Epoch 10/10
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2278 - accuracy: 0.9413 - val_loss: 0.7083 - val_accuracy: 0.7790
# 79/79 [==============================] - 2s 29ms/step - loss: 0.7083 - accuracy: 0.7790
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_36 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_36 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_72 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_73 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_72 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_73 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 79/79 [==============================] - 12s 114ms/step - loss: 0.7146 - accuracy: 0.5969 - val_loss: 0.6111 - val_accuracy: 0.7262
# Epoch 2/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5907 - accuracy: 0.7737 - val_loss: 0.5370 - val_accuracy: 0.7683
# Epoch 3/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.4915 - accuracy: 0.8282 - val_loss: 0.5145 - val_accuracy: 0.7690
# Epoch 4/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4254 - accuracy: 0.8645 - val_loss: 0.5518 - val_accuracy: 0.7813
# Epoch 5/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3746 - accuracy: 0.8854 - val_loss: 0.5287 - val_accuracy: 0.7782
# Epoch 6/15
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3313 - accuracy: 0.8995 - val_loss: 0.5346 - val_accuracy: 0.7825
# Epoch 7/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2996 - accuracy: 0.9128 - val_loss: 0.4783 - val_accuracy: 0.7833
# Epoch 8/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2770 - accuracy: 0.9215 - val_loss: 0.5669 - val_accuracy: 0.7778
# Epoch 9/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2484 - accuracy: 0.9325 - val_loss: 0.6387 - val_accuracy: 0.7810
# Epoch 10/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2407 - accuracy: 0.9356 - val_loss: 0.6747 - val_accuracy: 0.7806
# Epoch 11/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2231 - accuracy: 0.9438 - val_loss: 0.6484 - val_accuracy: 0.7698
# Epoch 12/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2031 - accuracy: 0.9491 - val_loss: 0.6932 - val_accuracy: 0.7702
# Epoch 13/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1943 - accuracy: 0.9501 - val_loss: 0.6446 - val_accuracy: 0.7540
# Epoch 14/15
# 79/79 [==============================] - 8s 106ms/step - loss: 0.1804 - accuracy: 0.9549 - val_loss: 0.9373 - val_accuracy: 0.7639
# Epoch 15/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1638 - accuracy: 0.9597 - val_loss: 1.0072 - val_accuracy: 0.7667
# 79/79 [==============================] - 2s 29ms/step - loss: 1.0072 - accuracy: 0.7667
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_37 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_37 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_74 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_75 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_74 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_75 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 79/79 [==============================] - 12s 115ms/step - loss: 0.6966 - accuracy: 0.6387 - val_loss: 0.6195 - val_accuracy: 0.7004
# Epoch 2/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5596 - accuracy: 0.7775 - val_loss: 0.5184 - val_accuracy: 0.7762
# Epoch 3/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4699 - accuracy: 0.8176 - val_loss: 0.4868 - val_accuracy: 0.7750
# Epoch 4/15
# 79/79 [==============================] - 8s 106ms/step - loss: 0.4154 - accuracy: 0.8528 - val_loss: 0.4657 - val_accuracy: 0.7929
# Epoch 5/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3624 - accuracy: 0.8732 - val_loss: 0.5490 - val_accuracy: 0.7790
# Epoch 6/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3301 - accuracy: 0.8874 - val_loss: 0.5111 - val_accuracy: 0.7857
# Epoch 7/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2944 - accuracy: 0.8971 - val_loss: 0.6382 - val_accuracy: 0.7782
# Epoch 8/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2616 - accuracy: 0.9065 - val_loss: 0.6596 - val_accuracy: 0.7845
# Epoch 9/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2322 - accuracy: 0.9187 - val_loss: 0.6651 - val_accuracy: 0.7714
# Epoch 10/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2189 - accuracy: 0.9174 - val_loss: 0.7187 - val_accuracy: 0.7706
# Epoch 11/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1926 - accuracy: 0.9307 - val_loss: 0.7510 - val_accuracy: 0.7766
# Epoch 12/15
# 79/79 [==============================] - 8s 106ms/step - loss: 0.1783 - accuracy: 0.9339 - val_loss: 0.8077 - val_accuracy: 0.7683
# Epoch 13/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1618 - accuracy: 0.9380 - val_loss: 0.9886 - val_accuracy: 0.7786
# Epoch 14/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1546 - accuracy: 0.9431 - val_loss: 1.0620 - val_accuracy: 0.7698
# Epoch 15/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1428 - accuracy: 0.9415 - val_loss: 1.0545 - val_accuracy: 0.7714
# 79/79 [==============================] - 2s 31ms/step - loss: 1.0545 - accuracy: 0.7714
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_38 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_38 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_76 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_77 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_76 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_77 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6879 - accuracy: 0.6527 - val_loss: 0.5624 - val_accuracy: 0.7536
# Epoch 2/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5275 - accuracy: 0.8018 - val_loss: 0.5094 - val_accuracy: 0.7794
# Epoch 3/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4380 - accuracy: 0.8495 - val_loss: 0.5074 - val_accuracy: 0.7885
# Epoch 4/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3774 - accuracy: 0.8798 - val_loss: 0.5258 - val_accuracy: 0.7679
# Epoch 5/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3285 - accuracy: 0.8970 - val_loss: 0.6180 - val_accuracy: 0.7317
# Epoch 6/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2983 - accuracy: 0.9084 - val_loss: 0.5524 - val_accuracy: 0.7627
# Epoch 7/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2643 - accuracy: 0.9179 - val_loss: 0.6391 - val_accuracy: 0.7722
# Epoch 8/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2355 - accuracy: 0.9254 - val_loss: 0.6622 - val_accuracy: 0.7690
# Epoch 9/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2099 - accuracy: 0.9370 - val_loss: 0.6983 - val_accuracy: 0.7706
# Epoch 10/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1842 - accuracy: 0.9400 - val_loss: 0.7602 - val_accuracy: 0.7679
# Epoch 11/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1742 - accuracy: 0.9453 - val_loss: 0.9689 - val_accuracy: 0.7587
# Epoch 12/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1644 - accuracy: 0.9521 - val_loss: 0.9045 - val_accuracy: 0.7567
# Epoch 13/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1490 - accuracy: 0.9556 - val_loss: 0.8906 - val_accuracy: 0.7571
# Epoch 14/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1399 - accuracy: 0.9580 - val_loss: 0.9694 - val_accuracy: 0.7623
# Epoch 15/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1223 - accuracy: 0.9629 - val_loss: 1.2495 - val_accuracy: 0.7567
# 79/79 [==============================] - 2s 29ms/step - loss: 1.2495 - accuracy: 0.7567
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_39 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_39 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_78 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_79 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_78 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_79 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 79/79 [==============================] - 12s 112ms/step - loss: 0.6948 - accuracy: 0.6335 - val_loss: 0.5986 - val_accuracy: 0.7187
# Epoch 2/15
# 79/79 [==============================] - 8s 106ms/step - loss: 0.5367 - accuracy: 0.7685 - val_loss: 0.5015 - val_accuracy: 0.7710
# Epoch 3/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4522 - accuracy: 0.8077 - val_loss: 0.5102 - val_accuracy: 0.7694
# Epoch 4/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3928 - accuracy: 0.8359 - val_loss: 0.5225 - val_accuracy: 0.7821
# Epoch 5/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3492 - accuracy: 0.8519 - val_loss: 0.5119 - val_accuracy: 0.7778
# Epoch 6/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3100 - accuracy: 0.8687 - val_loss: 0.5414 - val_accuracy: 0.7623
# Epoch 7/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2880 - accuracy: 0.8727 - val_loss: 0.6417 - val_accuracy: 0.7623
# Epoch 8/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2632 - accuracy: 0.8826 - val_loss: 0.6918 - val_accuracy: 0.7583
# Epoch 9/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2471 - accuracy: 0.8909 - val_loss: 0.7729 - val_accuracy: 0.7651
# Epoch 10/15
# 79/79 [==============================] - 8s 107ms/step - loss: 0.2324 - accuracy: 0.8931 - val_loss: 0.6815 - val_accuracy: 0.7579
# Epoch 11/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2030 - accuracy: 0.9078 - val_loss: 0.7888 - val_accuracy: 0.7595
# Epoch 12/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1905 - accuracy: 0.9489 - val_loss: 0.8600 - val_accuracy: 0.7575
# Epoch 13/15
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1756 - accuracy: 0.9498 - val_loss: 0.9000 - val_accuracy: 0.7488
# Epoch 14/15
# 79/79 [==============================] - 8s 106ms/step - loss: 0.1590 - accuracy: 0.9597 - val_loss: 0.8320 - val_accuracy: 0.7575
# Epoch 15/15
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1479 - accuracy: 0.9621 - val_loss: 0.8835 - val_accuracy: 0.7452
# 79/79 [==============================] - 2s 28ms/step - loss: 0.8835 - accuracy: 0.7452
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_40 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_40 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_80 (LSTM)               (None, None, 32)          42624
# ...
# _________________________________________________________________
# dense_85 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6741 - accuracy: 0.6594 - val_loss: 0.5564 - val_accuracy: 0.7567
# Epoch 2/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5059 - accuracy: 0.7986 - val_loss: 0.5036 - val_accuracy: 0.7762
# Epoch 3/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4161 - accuracy: 0.8534 - val_loss: 0.4859 - val_accuracy: 0.7802
# Epoch 4/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3567 - accuracy: 0.8810 - val_loss: 0.4969 - val_accuracy: 0.7893
# Epoch 5/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3154 - accuracy: 0.8939 - val_loss: 0.5190 - val_accuracy: 0.7766
# Epoch 6/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2837 - accuracy: 0.9117 - val_loss: 0.6092 - val_accuracy: 0.7845
# Epoch 7/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2465 - accuracy: 0.9189 - val_loss: 0.5606 - val_accuracy: 0.7698
# Epoch 8/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2139 - accuracy: 0.9343 - val_loss: 0.6693 - val_accuracy: 0.7647
# Epoch 9/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2027 - accuracy: 0.9378 - val_loss: 0.7480 - val_accuracy: 0.7782
# Epoch 10/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1750 - accuracy: 0.9481 - val_loss: 0.8445 - val_accuracy: 0.7643
# Epoch 11/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1568 - accuracy: 0.9532 - val_loss: 0.8113 - val_accuracy: 0.7571
# Epoch 12/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1446 - accuracy: 0.9566 - val_loss: 0.8571 - val_accuracy: 0.7571
# Epoch 13/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1373 - accuracy: 0.9588 - val_loss: 1.0414 - val_accuracy: 0.7679
# Epoch 14/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1344 - accuracy: 0.9597 - val_loss: 1.0340 - val_accuracy: 0.7599
# Epoch 15/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1223 - accuracy: 0.9645 - val_loss: 1.0180 - val_accuracy: 0.7579
# Epoch 16/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1096 - accuracy: 0.9669 - val_loss: 1.2112 - val_accuracy: 0.7591
# Epoch 17/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1060 - accuracy: 0.9695 - val_loss: 0.9938 - val_accuracy: 0.7587
# Epoch 18/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1066 - accuracy: 0.9674 - val_loss: 1.2408 - val_accuracy: 0.7480
# Epoch 19/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1017 - accuracy: 0.9694 - val_loss: 1.2382 - val_accuracy: 0.7619
# Epoch 20/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.0990 - accuracy: 0.9710 - val_loss: 1.3926 - val_accuracy: 0.7563
# 79/79 [==============================] - 2s 29ms/step - loss: 1.3926 - accuracy: 0.7563
# Model: "sequential_43"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_43 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_43 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_86 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_87 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_86 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_87 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 79/79 [==============================] - 12s 113ms/step - loss: 0.6999 - accuracy: 0.5784 - val_loss: 0.5906 - val_accuracy: 0.7274
# Epoch 2/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.5614 - accuracy: 0.7172 - val_loss: 0.5294 - val_accuracy: 0.7643
# Epoch 3/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4854 - accuracy: 0.7596 - val_loss: 0.5362 - val_accuracy: 0.7607
# Epoch 4/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4199 - accuracy: 0.7883 - val_loss: 0.5347 - val_accuracy: 0.7714
# Epoch 5/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.3928 - accuracy: 0.7993 - val_loss: 0.5773 - val_accuracy: 0.7635
# Epoch 6/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3611 - accuracy: 0.8640 - val_loss: 0.5041 - val_accuracy: 0.7706
# Epoch 7/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3235 - accuracy: 0.8945 - val_loss: 0.5804 - val_accuracy: 0.7698
# Epoch 8/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2815 - accuracy: 0.9108 - val_loss: 0.6296 - val_accuracy: 0.7726
# Epoch 9/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2544 - accuracy: 0.9168 - val_loss: 0.8007 - val_accuracy: 0.7544
# Epoch 10/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2187 - accuracy: 0.9286 - val_loss: 0.8795 - val_accuracy: 0.7599
# Epoch 11/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2040 - accuracy: 0.9338 - val_loss: 1.0209 - val_accuracy: 0.7500
# Epoch 12/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1854 - accuracy: 0.9378 - val_loss: 0.9172 - val_accuracy: 0.7655
# Epoch 13/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1716 - accuracy: 0.9398 - val_loss: 0.9447 - val_accuracy: 0.7560
# Epoch 14/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1503 - accuracy: 0.9462 - val_loss: 0.9359 - val_accuracy: 0.7385
# Epoch 15/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1481 - accuracy: 0.9445 - val_loss: 1.0943 - val_accuracy: 0.7575
# Epoch 16/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1407 - accuracy: 0.9490 - val_loss: 0.8976 - val_accuracy: 0.7464
# Epoch 17/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1268 - accuracy: 0.9526 - val_loss: 1.0140 - val_accuracy: 0.7401
# Epoch 18/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1213 - accuracy: 0.9537 - val_loss: 1.1809 - val_accuracy: 0.7468
# Epoch 19/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1212 - accuracy: 0.9548 - val_loss: 1.0305 - val_accuracy: 0.7389
# Epoch 20/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1052 - accuracy: 0.9585 - val_loss: 1.3466 - val_accuracy: 0.7381
# 79/79 [==============================] - 2s 29ms/step - loss: 1.3466 - accuracy: 0.7381
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_44 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_44 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_88 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_89 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_88 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_89 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 79/79 [==============================] - 12s 115ms/step - loss: 0.7010 - accuracy: 0.6413 - val_loss: 0.6025 - val_accuracy: 0.7492
# Epoch 2/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5634 - accuracy: 0.7896 - val_loss: 0.5285 - val_accuracy: 0.7738
# Epoch 3/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.4797 - accuracy: 0.8450 - val_loss: 0.5469 - val_accuracy: 0.7655
# Epoch 4/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4299 - accuracy: 0.8685 - val_loss: 0.5133 - val_accuracy: 0.7698
# Epoch 5/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3905 - accuracy: 0.8891 - val_loss: 0.5982 - val_accuracy: 0.7627
# Epoch 6/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3529 - accuracy: 0.9036 - val_loss: 0.5270 - val_accuracy: 0.7524
# Epoch 7/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3212 - accuracy: 0.9220 - val_loss: 0.6911 - val_accuracy: 0.7607
# Epoch 8/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3032 - accuracy: 0.9225 - val_loss: 0.5946 - val_accuracy: 0.7579
# Epoch 9/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2676 - accuracy: 0.9409 - val_loss: 0.6746 - val_accuracy: 0.7508
# Epoch 10/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2524 - accuracy: 0.9438 - val_loss: 0.9668 - val_accuracy: 0.7480
# Epoch 11/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2322 - accuracy: 0.9496 - val_loss: 0.6762 - val_accuracy: 0.7123
# Epoch 12/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2291 - accuracy: 0.9463 - val_loss: 0.7317 - val_accuracy: 0.7313
# Epoch 13/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2095 - accuracy: 0.9537 - val_loss: 0.9336 - val_accuracy: 0.7333
# Epoch 14/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1988 - accuracy: 0.9569 - val_loss: 0.8880 - val_accuracy: 0.7325
# Epoch 15/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1818 - accuracy: 0.9633 - val_loss: 0.9906 - val_accuracy: 0.7353
# Epoch 16/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1769 - accuracy: 0.9624 - val_loss: 0.8291 - val_accuracy: 0.7306
# Epoch 17/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1645 - accuracy: 0.9659 - val_loss: 0.9598 - val_accuracy: 0.7313
# Epoch 18/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1582 - accuracy: 0.9688 - val_loss: 1.1237 - val_accuracy: 0.7306
# Epoch 19/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.1471 - accuracy: 0.9710 - val_loss: 1.1162 - val_accuracy: 0.7353
# Epoch 20/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1415 - accuracy: 0.9711 - val_loss: 1.1098 - val_accuracy: 0.7214
# 79/79 [==============================] - 3s 32ms/step - loss: 1.1098 - accuracy: 0.7214
# Model: "sequential_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_45 (Embedding)     (None, None, 300)         3000000
# _________________________________________________________________
# spatial_dropout1d_45 (Spatia (None, None, 300)         0
# _________________________________________________________________
# lstm_90 (LSTM)               (None, None, 32)          42624
# _________________________________________________________________
# lstm_91 (LSTM)               (None, 32)                8320
# _________________________________________________________________
# dense_90 (Dense)             (None, 8)                 264
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 8)                 0
# _________________________________________________________________
# dense_91 (Dense)             (None, 2)                 18
# =================================================================
# Total params: 3,051,226
# Trainable params: 3,051,226
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 79/79 [==============================] - 13s 112ms/step - loss: 0.6753 - accuracy: 0.6678 - val_loss: 0.5662 - val_accuracy: 0.7540
# Epoch 2/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.5277 - accuracy: 0.8046 - val_loss: 0.5121 - val_accuracy: 0.7754
# Epoch 3/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.4385 - accuracy: 0.8550 - val_loss: 0.5268 - val_accuracy: 0.7667
# Epoch 4/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.3787 - accuracy: 0.8802 - val_loss: 0.5482 - val_accuracy: 0.7587
# Epoch 5/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3406 - accuracy: 0.8952 - val_loss: 0.5013 - val_accuracy: 0.7845
# Epoch 6/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.3072 - accuracy: 0.9103 - val_loss: 0.4967 - val_accuracy: 0.7885
# Epoch 7/20
# 79/79 [==============================] - 8s 108ms/step - loss: 0.2798 - accuracy: 0.9192 - val_loss: 0.5242 - val_accuracy: 0.7746
# Epoch 8/20
# 79/79 [==============================] - 8s 106ms/step - loss: 0.2552 - accuracy: 0.9292 - val_loss: 0.5778 - val_accuracy: 0.7762
# Epoch 9/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.2279 - accuracy: 0.9361 - val_loss: 0.6414 - val_accuracy: 0.7758
# Epoch 10/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2119 - accuracy: 0.9423 - val_loss: 0.7037 - val_accuracy: 0.7770
# Epoch 11/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.2041 - accuracy: 0.9483 - val_loss: 0.9771 - val_accuracy: 0.7663
# Epoch 12/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1929 - accuracy: 0.9483 - val_loss: 0.7427 - val_accuracy: 0.7782
# Epoch 13/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1666 - accuracy: 0.9567 - val_loss: 0.7225 - val_accuracy: 0.7782
# Epoch 14/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1612 - accuracy: 0.9593 - val_loss: 1.1319 - val_accuracy: 0.7730
# Epoch 15/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1519 - accuracy: 0.9657 - val_loss: 0.9119 - val_accuracy: 0.7607
# Epoch 16/20
# 79/79 [==============================] - 8s 105ms/step - loss: 0.1443 - accuracy: 0.9660 - val_loss: 1.0119 - val_accuracy: 0.7659
# Epoch 17/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1329 - accuracy: 0.9680 - val_loss: 1.0157 - val_accuracy: 0.7659
# Epoch 18/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1232 - accuracy: 0.9691 - val_loss: 0.9632 - val_accuracy: 0.7468
# Epoch 19/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1175 - accuracy: 0.9708 - val_loss: 1.2199 - val_accuracy: 0.7508
# Epoch 20/20
# 79/79 [==============================] - 8s 104ms/step - loss: 0.1066 - accuracy: 0.9762 - val_loss: 1.3028 - val_accuracy: 0.7599
# 79/79 [==============================] - 2s 29ms/step - loss: 1.3028 - accuracy: 0.7599

# %%
for batch in batch_size_tes:
    print(globals()['jumlah_fold_epoh%s'%epoh])
# Out:
#       21     22     23     24     25
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520
#       21     22     23     24     25
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520
#       21     22     23     24     25
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520
#       21     22     23     24     25
# 0  10080  10080  10080  10080  10080
# 1   2520   2520   2520   2520   2520

# %%
data_kfold_epoh3
# Out:
#           1         2         3         4         5
# 0  0.484342  0.488121  0.526685  0.542639  0.645896
# 1  0.786905  0.786508  0.755159  0.766270  0.747222

# %%
data_kfold_epoh5
# Out:
#          6         7         8         9         10
# 0  0.513130  0.510093  0.535718  0.579795  0.499848
# 1  0.784921  0.778968  0.780556  0.776984  0.780556

# %%
data_kfold_epoh10
# Out:
#          11        12        13        14        15
# 0  0.648493  0.783095  1.049938  0.724986  0.708311
# 1  0.778968  0.755159  0.755159  0.757937  0.778968

# %%
data_kfold_epoh15
# Out:
#          16        17        18        19        20
# 0  1.007234  1.054546  1.249507  0.883475  0.883818
# 1  0.766667  0.771429  0.756746  0.745238  0.770635

# %%
data_kfold_epoh20
# Out:
#          21        22        23        24        25
# 0  0.758511  1.392615  1.346600  1.109844  1.302765
# 1  0.727381  0.756349  0.738095  0.721429  0.759921

# %% [markdown]
# nilai rata rata akurasi dan loss

# %%
data_eval_kfold = pd.DataFrame()

for epoh in epoh_tes:
    print(globals()['data_kfold_epoh%s'%epoh].mean(axis=1))
# Out:
# 0    0.537537
# 1    0.768413
# dtype: float64
# 0    0.527717
# 1    0.780397
# dtype: float64
# 0    0.782965
# 1    0.765238
# dtype: float64
# 0    1.015716
# 1    0.762143
# dtype: float64
# 0    1.182067
# 1    0.740635
# dtype: float64

# %% [markdown]
# evaluasi model optimal dari epoch

# %%
#evaluasi model optimal dan simpan model ke format h5

for epoh in epoh_tes:
    globals()['model_fold_%s' %epoh].evaluate(X_test,y_test)
    globals()['model_fold_%s' %epoh].save("modelfold%s.h5"%epoh)
# Out:
# 44/44 [==============================] - 1s 29ms/step - loss: 0.5840 - accuracy: 0.7771
# 44/44 [==============================] - 1s 28ms/step - loss: 0.4693 - accuracy: 0.8007
# 44/44 [==============================] - 1s 29ms/step - loss: 0.7152 - accuracy: 0.7814
# 44/44 [==============================] - 1s 29ms/step - loss: 0.8671 - accuracy: 0.7679
# 44/44 [==============================] - 1s 29ms/step - loss: 1.2366 - accuracy: 0.7571

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
y_pred = model_fold_5.predict(X_test)

matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))

f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1)), annot=True, fmt=".0f", ax=ax)
"""plt.xlabel("y_head")
plt.ylabel("y_true")"""
plt.show()

# %%
report = classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1),target_names=['negative','positive'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.77      0.85      0.81       691
#     positive       0.84      0.75      0.79       709
#
#     accuracy                           0.80      1400
#    macro avg       0.80      0.80      0.80      1400
# weighted avg       0.80      0.80      0.80      1400

# %% [markdown]
# Simpan Tokenizer

# %%
import pickle

# saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# loading
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
from keras.models import load_model

loaded_model = load_model("./modelfold5.h5")
loss, accuracy = loaded_model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 2s 28ms/step - loss: 0.4693 - accuracy: 0.8007
